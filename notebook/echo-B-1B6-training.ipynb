# %% [markdown]
# # Init the model using blink original repo
# (cancel the train after it init finish)
#
# ```bash
# python train.py --load_model "" --proj_dir "out-B" \
# --data_file "../data/enwik8.npy" --data_type "numpy" --vocab_size 50277 \
# --ctx_len 2048 --epoch_steps 5000 --epoch_count 20 --epoch_begin 0 --epoch_save 1 \
# --micro_bsz 64 --n_layer 48 --n_embd 1536 --pre_ffn 0 --head_qk 0 \
# --lr_init 8e-4 --lr_final 2e-4 --warmup_steps 0 --beta1 0.9 --beta2 0.99 --adam_eps 1e-8 \
# --accelerator gpu --devices 1 --precision bf16 --strategy deepspeed_stage_2_offload --grad_cp 0
# ```
#
# Copy the `rwkv-init.pth` model from `out-B` dir, into the `build` dir as `Echo-B-Init-1B6.pth`

# %%
# Run the trainer
# !cd ../RWKV-v4neo && python new_train.py fit -c ./echo-B-1B6.yaml
# Out:
# Setting ds_accelerator to cuda (auto detect)
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 2607739452
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 2607739452
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230621_114021-67ndndub
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Resuming run Echo-B-1B4 Foundation-enwiki-training
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-Memory-Experiment
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-Memory-Experiment/runs/67ndndub
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_2048_bf16/build.ninja...
# Building extension module wkv_2048_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_2048_bf16...
# Found cached dataset text (/home/picocreator/.cache/huggingface/datasets/text/data_path-44508f03a521e619/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 158.56it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/text/data_path-44508f03a521e619/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2/cache-5808f7aea1e40ad0_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/text/data_path-44508f03a521e619/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2/cache-fd59e8ce354a04e7_*_of_00016.arrow
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 2607739452
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-06-21 11:40:33,519] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# You are using a CUDA device ('NVIDIA GeForce RTX 4090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:612: UserWarning: Checkpoint directory /home/picocreator/rwkv-proj/my-RWKV-LM-LoRA/checkpoint/echo-B-1B4 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.3314788341522217 seconds
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.051985740661621094 seconds
# Rank: 0 partition count [1, 1, 1] and sizes[(1412478976, False), (98304, False), (98304, False)]
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005013942718505859 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 51.5 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 2.0 K
# 3 | head   | Linear     | 51.5 M
# --------------------------------------
# 1.4 B     Trainable params
# 0         Non-trainable params
# 1.4 B     Total params
# 5,650.702 Total estimated model params size (MB)
# Restoring states from the checkpoint path at /home/picocreator/rwkv-proj/my-RWKV-LM-LoRA/checkpoint/epoch=2-step=290.ckpt/
# [2023-06-21 11:40:47,522] [WARNING] [engine.py:2595:load_checkpoint] Unable to find latest file at /home/picocreator/rwkv-proj/my-RWKV-LM-LoRA/checkpoint/epoch=2-step=290.ckpt/latest, if trying to load latest checkpoint please ensure this file exists or pass an explicit checkpoint tag when loading a checkpoint.
# Traceback (most recent call last):
#   File "/home/picocreator/rwkv-proj/my-RWKV-LM-LoRA/RWKV-v4neo/new_train.py", line 12, in <module>
#     cli_main()
#   File "/home/picocreator/rwkv-proj/my-RWKV-LM-LoRA/RWKV-v4neo/new_train.py", line 8, in cli_main
#     LightningCLI(RWKV, get_data_module, save_config_kwargs={"overwrite": True})
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 922, in _run
#     self._checkpoint_connector._restore_modules_and_callbacks(ckpt_path)
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py", line 395, in _restore_modules_and_callbacks
#     self.resume_start(checkpoint_path)
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py", line 82, in resume_start
#     loaded_checkpoint = self.trainer.strategy.load_checkpoint(checkpoint_path)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/strategies/deepspeed.py", line 791, in load_checkpoint
#     raise MisconfigurationException(
# lightning.fabric.utilities.exceptions.MisconfigurationException: DeepSpeed was unable to load the checkpoint. Ensure you passed in a DeepSpeed compatible checkpoint or a single checkpoint file with `Trainer(strategy=DeepSpeedStrategy(load_full_weights=True))`.
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb: | 0.008 MB of 0.008 MB uploaded (0.000 MB deduped)
# wandb: Run summary:
# wandb:               epoch 2
# wandb:        real_ctx_len 2047
# wandb:             substep 11847
# wandb:          train/loss 7.28125
# wandb: trainer/global_step 292
# wandb:     validation/loss 8.60461
# wandb:
# wandb: 🚀 View run Echo-B-1B4 Foundation-enwiki-training at: https://wandb.ai/picocreator/RWKV-Memory-Experiment/runs/67ndndub
# wandb: Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230621_114021-67ndndub/logs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Run the trainer
# ----> 2 get_ipython().system('cd ../RWKV-v4neo && python new_train.py fit -c ./echo-B-1B4.yaml')
#
# File ~/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/ipykernel/zmqshell.py:649, in ZMQInteractiveShell.system_piped(self, cmd)
#     647         self.user_ns["_exit_code"] = system(cmd)
#     648 else:
# --> 649     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/IPython/utils/_process_posix.py:179, in ProcessHandler.system(self, cmd)
#     177         child.terminate(force=True)
#     178 # add isalive check, to ensure exitstatus is set:
# --> 179 child.isalive()
#     181 # We follow the subprocess pattern, returning either the exit status
#     182 # as a positive number, or the terminating signal as a negative
#     183 # number.
#     184 # on Linux, sh returns 128+n for signals terminating child processes on Linux
#     185 # on BSD (OS X), the signal code is set instead
#     186 if child.exitstatus is None:
#     187     # on WIFSIGNALED, pexpect sets signalstatus, leaving exitstatus=None
#
# File ~/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/pexpect/pty_spawn.py:705, in spawn.isalive(self)
#     703 ptyproc = self.ptyproc
#     704 with _wrap_ptyprocess_err():
# --> 705     alive = ptyproc.isalive()
#     707 if not alive:
#     708     self.status = ptyproc.status
#
# File ~/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/ptyprocess/ptyprocess.py:711, in PtyProcess.isalive(self)
#     708     waitpid_options = os.WNOHANG
#     710 try:
# --> 711     pid, status = os.waitpid(self.pid, waitpid_options)
#     712 except OSError as e:
#     713     # No child processes
#     714     if e.errno == errno.ECHILD:
#
# KeyboardInterrupt:
